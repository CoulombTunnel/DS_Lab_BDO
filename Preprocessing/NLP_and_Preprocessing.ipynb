# %% [markdown]
# # Labeling the attributes of the 2011, 2013, 2016 and 2022 json files
#
# This notebook uses the NLP models of Spacy, the country-converter, a dataset with cities and some other methods to label the attributes of the json files.

# %% [markdown]
# ### Import Libraries and download the English transformer model from Spacy

# %%
# Libraries
import pandas as pd
import json
import country_converter as coco
import spacy
from spacy import displacy

# %%
#!python3 -m spacy download en_core_web_trf

# %% [markdown]
# ### Function to label the attributes
#
# We label the attributes in the following sequence:
# - Spacy's NLP model classifies the attributes
# - country: The Country-Converter detects countries and changes their name to a standard
# - city: The attributes will be compared to a dataset of the biggest cities
# - org: Organisations with a typical ending for companies (gmbh, ag, ...) will be identified
# - dep: Typical company departments are detected.
# - other: Some unlabeled attributes remain.

# %%
# Load Spacy English language model (outside of the function, so it does not have to be loaded everytime the function is called)
NER = spacy.load("en_core_web_trf")


def label_data(network_file_path):

    # Read the JSON-file
    with open(network_file_path, 'r', encoding='utf-8') as file:
        data = json.load(file)

    # List to store labeled data
    labeled_data = []

    # Process each attribute in the JSON file
    for key, values in data.items():
        for value in values:
            doc = NER(value)
            entities = ', '.join([ent.label_ for ent in doc.ents])  # Convert the list of entities to a string
            entities = entities.lower()
            labeled_data.append({'company': key, 'attribute': value, 'label': entities})

    # Convert list to DataFrame
    labeled_data_df = pd.DataFrame(labeled_data)

    # Read the cities and change them to lowercase
    with open('all_cities.txt', 'r') as file:
        cities = [city.strip().lower() for city in file.readlines()]

    # List with typical company endings
    endings = [' gmbh', ' sa', ' ltd', ' limited', ' ag', ' group']

    # List with relevant departments (some of them are from https://simplicable.com/en/company-departments)
    departments = ['compliance', 'corporate communication', 'employee relations', 'employee services', 'executive management', 'executive support',
                'facilities management', 'accounting', 'human resources', 'internal audit', 'legal affairs', 'media relations', 'office management',
                'quality assurance', 'reception services', 'recruitment', 'risk management', 'advertising', 'brand management', 'creative services', 
                'customer engagement', 'marketing', 'product development', 'product management', 'public relations', 'sales', 'customer service', 
                'distribution', 'inventory management', 'logistics', 'maintenance', 'operations management', 'procurement', 'purchasing', 'production',
                'project management', 'quality control', 'supplier management', 'supply chain management', 'information technology']

    # Check each row and update the labels
    for index, row in labeled_data_df.iterrows():
        
        # Try to convert the attribute to name_short
        try:
            converted = coco.convert(names=row['attribute'], to='name_short')

            # If the Conversion was successful, update the attribute and change the label to 'country'
            if converted != 'not found':
                labeled_data_df.at[index, 'attribute'] = converted.lower()
                labeled_data_df.at[index, 'label'] = 'country'
                continue    # go to the next attribute

        # If the Conversion was not successful, check for city, company and department
        except Exception:
            pass

        # Check if the attribute is a city and update the label
        if row['attribute'] in cities:
            labeled_data_df.at[index, 'label'] = 'city'
        
        # Check if the attribute ends with one of the typical company endings; in this case, change the label to 'org'
        elif any(row['attribute'].endswith(end) for end in endings):
            labeled_data_df.at[index, 'label'] = 'org'

        # Check if the attribute contains one of the department names and update the label only if it was empty before
        elif any(department in row['attribute'] for department in departments) and row['label'] == '':
            labeled_data_df.at[index, 'label'] = 'dep'

        # Check if the label is empty or there are more labels than one for this attribute (this is the case when spacy's result were two or more labels for one attribute)
        elif pd.isna(row['label']) or row['label'] == '' or row['label'] is None or ',' in str(row['label']):
            labeled_data_df.at[index, 'label'] = 'other'
        
    # Export the labeled data as csv
    output_file_name = 'labeled_' + network_file_path.split('.')[0] + '.csv'
    labeled_data_df.to_csv(output_file_name, index=False)

# %% [markdown]
# #### Apply the function to the 2011 file

# %%
#label_data('../Files/BDO_uploads/network_2011_update_28112023.txt')

# %% [markdown]
# #### Apply the function to the 2013 file

# %%
#label_data('../Files/BDO_uploads/network_2011_update_28112023.txt')

# %% [markdown]
# #### Apply the function to the 2016 file

# %%
#label_data('../Files/BDO_uploads/network_2011_update_28112023.txt')

# %% [markdown]
# #### Apply the function to the 2022 file

# %%
#label_data('../Files/BDO_uploads/network_2011_update_28112023.txt')

# %% [markdown]
# # Improvement of the labeling algorithm
#
# The function above takes a long for labeling the datasets. Our further work is therefore based on the already labeled data. In this section we attempt to further refine the classification.

# %%
# Read the previously labeled csv files
testfile_2011 = pd.read_csv('labeled_network_2011_TEST.csv')
labeled_2011 = pd.read_csv('labeled_network_2011_update_28112023.csv')
labeled_2013 = pd.read_csv('labeled_network_2013_update_28112023.csv')
labeled_2016 = pd.read_csv('labeled_network_2016_update_28112023.csv')
labeled_2022 = pd.read_csv('labeled_network_2022_update_28112023.csv')

# %% [markdown]
# ### Use the German transformer model from Spacy

# %% [markdown]
# As suggested by BDO, we try to use the German transformer model from Spacy instead of the English one. Before labeling the whole data again - which takes a long time - we apply this model on a smaller test set with with three Austrian companies Raiffeisen Bank International, Erste Bank and Andritz.

# %%
#!python3 -m spacy download de_dep_news_trf

# %%
# Load Spacy German language model
NER_de = spacy.load("de_dep_news_trf")

# Function to label the text using the German transformer model
def label_text_de(text):
    doc = NER_de(text)
    if doc.ents:  # if the model found entities
        return doc.ents[0].label_  # return the label of the first entity
    else:
        return "other"  # if no entity found, return 'other'

# Apply the function to the 'attribute' column to create the new 'label_de' column
testfile_2011_de = testfile_2011
testfile_2011_de['label_de'] = testfile_2011_de['attribute'].apply(label_text_de)

# %%
# Define a function for printing a full dataframe
def print_full(df):
    pd.set_option('display.max_rows', len(df))
    print(df)
    pd.reset_option('display.max_rows')

# %%
print_full(testfile_2011_de)
# Out:
#                                company  \
# 0     raiffeisen bank international ag
# 1     raiffeisen bank international ag
# 2     raiffeisen bank international ag
# 3     raiffeisen bank international ag
# 4     raiffeisen bank international ag
# 5     raiffeisen bank international ag
# 6     raiffeisen bank international ag
# 7     raiffeisen bank international ag
# 8     raiffeisen bank international ag
# 9     raiffeisen bank international ag
# 10    raiffeisen bank international ag
# 11    raiffeisen bank international ag
# 12    raiffeisen bank international ag
# 13    raiffeisen bank international ag
# 14    raiffeisen bank international ag
# 15    raiffeisen bank international ag
# 16    raiffeisen bank international ag
# 17    raiffeisen bank international ag
# 18    raiffeisen bank international ag
# 19    raiffeisen bank international ag
# 20    raiffeisen bank international ag
# 21    raiffeisen bank international ag
# 22    raiffeisen bank international ag
# 23    raiffeisen bank international ag
# 24    raiffeisen bank international ag
# 522                erste group bank ag
# 523                erste group bank ag
# 524                erste group bank ag
# 525                erste group bank ag
# 526                erste group bank ag
# 527                erste group bank ag
# 528                erste group bank ag
# 529                erste group bank ag
# 530                erste group bank ag
# 531                erste group bank ag
# 532                erste group bank ag
# 533                erste group bank ag
# 534                erste group bank ag
# 535                erste group bank ag
# 536                erste group bank ag
# 537                erste group bank ag
# 538                erste group bank ag
# 539                erste group bank ag
# 540                erste group bank ag
# 541                erste group bank ag
# 542                erste group bank ag
# 543                erste group bank ag
# 544                erste group bank ag
# 545                erste group bank ag
# 546                erste group bank ag
# 547                erste group bank ag
# 548                erste group bank ag
# 549                erste group bank ag
# 550                erste group bank ag
# 551                erste group bank ag
# 552                erste group bank ag
# 553                erste group bank ag
# 554                erste group bank ag
# 555                erste group bank ag
# 556                erste group bank ag
# 557                erste group bank ag
# 558                erste group bank ag
# 559                erste group bank ag
# 560                erste group bank ag
# 561                erste group bank ag
# 562                erste group bank ag
# 563                erste group bank ag
# 564                erste group bank ag
# 565                erste group bank ag
# 566                erste group bank ag
# 567                erste group bank ag
# 568                erste group bank ag
# 569                erste group bank ag
# 570                erste group bank ag
# 571                erste group bank ag
# 572                erste group bank ag
# 573                erste group bank ag
# 574                erste group bank ag
# 575                erste group bank ag
# 576                erste group bank ag
# 577                erste group bank ag
# 578                erste group bank ag
# 579                erste group bank ag
# 580                erste group bank ag
# 581                erste group bank ag
# 582                erste group bank ag
# 583                erste group bank ag
# 584                erste group bank ag
# 585                erste group bank ag
# 586                erste group bank ag
# 587                erste group bank ag
# 588                erste group bank ag
# 589                erste group bank ag
# 590                erste group bank ag
# 591                erste group bank ag
# 592                erste group bank ag
# 593                erste group bank ag
# 594                erste group bank ag
# 595                erste group bank ag
# 596                erste group bank ag
# 597                erste group bank ag
# 598                erste group bank ag
# 599                erste group bank ag
# 600                erste group bank ag
# 601                erste group bank ag
# 602                erste group bank ag
# 603                erste group bank ag
# 604                erste group bank ag
# 605                erste group bank ag
# 606                erste group bank ag
# 607                erste group bank ag
# 608                erste group bank ag
# 609                erste group bank ag
# 610                erste group bank ag
# 611                erste group bank ag
# 612                erste group bank ag
# 613                erste group bank ag
# 614                erste group bank ag
# 615                erste group bank ag
# 616                erste group bank ag
# 617                erste group bank ag
# 618                erste group bank ag
# 619                erste group bank ag
# 620                erste group bank ag
# 621                erste group bank ag
# 622                erste group bank ag
# 623                erste group bank ag
# 624                erste group bank ag
# 625                erste group bank ag
# 626                erste group bank ag
# 627                erste group bank ag
# 628                erste group bank ag
# 629                erste group bank ag
# 630                erste group bank ag
# 631                erste group bank ag
# 632                erste group bank ag
# 633                erste group bank ag
# 634                erste group bank ag
# 635                erste group bank ag
# 636                erste group bank ag
# 637                erste group bank ag
# 638                erste group bank ag
# 639                erste group bank ag
# 640                erste group bank ag
# 641                erste group bank ag
# 642                erste group bank ag
# 643                erste group bank ag
# 644                erste group bank ag
# 645                erste group bank ag
# 646                erste group bank ag
# 647                erste group bank ag
# 648                erste group bank ag
# 649                erste group bank ag
# 650                erste group bank ag
# 651                erste group bank ag
# 652                erste group bank ag
# 653                erste group bank ag
# 654                erste group bank ag
# 655                erste group bank ag
# 656                erste group bank ag
# 657                erste group bank ag
# 658                erste group bank ag
# 659                erste group bank ag
# 660                erste group bank ag
# 661                erste group bank ag
# 662                erste group bank ag
# 663                erste group bank ag
# 664                erste group bank ag
# 665                erste group bank ag
# 666                erste group bank ag
# 667                erste group bank ag
# 668                erste group bank ag
# 669                erste group bank ag
# 670                erste group bank ag
# 671                erste group bank ag
# 672                erste group bank ag
# 673                erste group bank ag
# 674                erste group bank ag
# 675                erste group bank ag
# 676                erste group bank ag
# 677                erste group bank ag
# 678                erste group bank ag
# 679                erste group bank ag
# 680                erste group bank ag
# 681                erste group bank ag
# 682                erste group bank ag
# 683                erste group bank ag
# 684                erste group bank ag
# 685                erste group bank ag
# 686                erste group bank ag
# 687                erste group bank ag
# 688                erste group bank ag
# 689                erste group bank ag
# 690                erste group bank ag
# 691                erste group bank ag
# 692                erste group bank ag
# 693                erste group bank ag
# 694                erste group bank ag
# 695                erste group bank ag
# 696                erste group bank ag
# 697                erste group bank ag
# 698                erste group bank ag
# 699                erste group bank ag
# 700                erste group bank ag
# 701                erste group bank ag
# 702                erste group bank ag
# 703                erste group bank ag
# 704                erste group bank ag
# 705                erste group bank ag
# 706                erste group bank ag
# 707                erste group bank ag
# 708                erste group bank ag
# 709                erste group bank ag
# 710                erste group bank ag
# 711                erste group bank ag
# 712                erste group bank ag
# 713                erste group bank ag
# 714                erste group bank ag
# 715                erste group bank ag
# 716                erste group bank ag
# 717                erste group bank ag
# 718                erste group bank ag
# 719                erste group bank ag
# 720                erste group bank ag
# 721                erste group bank ag
# 722                erste group bank ag
# 723                erste group bank ag
# 724                erste group bank ag
# 725                erste group bank ag
# 726                erste group bank ag
# 727                erste group bank ag
# 728                erste group bank ag
# 729                erste group bank ag
# 730                erste group bank ag
# 731                erste group bank ag
# 732                erste group bank ag
# 733                erste group bank ag
# 734                erste group bank ag
# 735                erste group bank ag
# 736                erste group bank ag
# 737                erste group bank ag
# 738                erste group bank ag
# 739                erste group bank ag
# 740                erste group bank ag
# 741                erste group bank ag
# 742                erste group bank ag
# 743                erste group bank ag
# 744                erste group bank ag
# 745                erste group bank ag
# 746                erste group bank ag
# 747                erste group bank ag
# 748                erste group bank ag
# 749                erste group bank ag
# 750                erste group bank ag
# 751                erste group bank ag
# 752                erste group bank ag
# 753                erste group bank ag
# 754                erste group bank ag
# 755                erste group bank ag
# 756                erste group bank ag
# 757                erste group bank ag
# 758                erste group bank ag
# 759                erste group bank ag
# 760                erste group bank ag
# 761                erste group bank ag
# 762                erste group bank ag
# 763                erste group bank ag
# 764                erste group bank ag
# 765                erste group bank ag
# 766                erste group bank ag
# 767                erste group bank ag
# 768                erste group bank ag
# 769                erste group bank ag
# 770                erste group bank ag
# 771                erste group bank ag
# 772                erste group bank ag
# 773                erste group bank ag
# 774                erste group bank ag
# 775                erste group bank ag
# 776                erste group bank ag
# 777                erste group bank ag
# 778                erste group bank ag
# 779                erste group bank ag
# 780                erste group bank ag
# 781                erste group bank ag
# 782                erste group bank ag
# 783                erste group bank ag
# 784                erste group bank ag
# 785                erste group bank ag
# 786                erste group bank ag
# 787                erste group bank ag
# 788                erste group bank ag
# 789                erste group bank ag
# 790                erste group bank ag
# 791                erste group bank ag
# 792                erste group bank ag
# 793                erste group bank ag
# 794                erste group bank ag
# 795                erste group bank ag
# 796                erste group bank ag
# 797                erste group bank ag
# 798                erste group bank ag
# 799                erste group bank ag
# 800                erste group bank ag
# 801                erste group bank ag
# 802                erste group bank ag
# 803                erste group bank ag
# 804                erste group bank ag
# 805                erste group bank ag
# 806                erste group bank ag
# 807                erste group bank ag
# 808                erste group bank ag
# 809                erste group bank ag
# 810                erste group bank ag
# 811                erste group bank ag
# 812                erste group bank ag
# 813                erste group bank ag
# 814                erste group bank ag
# 815                erste group bank ag
# 816                erste group bank ag
# 817                erste group bank ag
# 818                erste group bank ag
# 819                erste group bank ag
# 820                erste group bank ag
# 821                erste group bank ag
# 822                erste group bank ag
# 823                erste group bank ag
# 824                erste group bank ag
# 825                erste group bank ag
# 826                erste group bank ag
# 827                erste group bank ag
# 828                erste group bank ag
# 829                erste group bank ag
# 830                erste group bank ag
# 831                erste group bank ag
# 832                erste group bank ag
# 833                erste group bank ag
# 834                erste group bank ag
# 835                erste group bank ag
# 836                erste group bank ag
# 837                erste group bank ag
# 838                erste group bank ag
# 839                erste group bank ag
# 840                erste group bank ag
# 841                erste group bank ag
# 842                erste group bank ag
# 843                erste group bank ag
# 844                erste group bank ag
# 845                erste group bank ag
# 846                erste group bank ag
# 847                erste group bank ag
# 848                erste group bank ag
# 849                erste group bank ag
# 850                erste group bank ag
# 851                erste group bank ag
# 852                erste group bank ag
# 853                erste group bank ag
# 854                erste group bank ag
# 855                erste group bank ag
# 856                erste group bank ag
# 857                erste group bank ag
# 858                erste group bank ag
# 859                erste group bank ag
# 860                erste group bank ag
# 861                erste group bank ag
# 862                erste group bank ag
# 863                erste group bank ag
# 864                erste group bank ag
# 865                erste group bank ag
# 866                erste group bank ag
# 867                erste group bank ag
# 868                erste group bank ag
# 869                erste group bank ag
# 870                erste group bank ag
# 871                erste group bank ag
# 872                erste group bank ag
# 873                erste group bank ag
# 874                erste group bank ag
# 875                erste group bank ag
# 876                erste group bank ag
# 877                erste group bank ag
# 878                erste group bank ag
# 879                erste group bank ag
# 880                erste group bank ag
# 881                erste group bank ag
# 882                erste group bank ag
# 883                erste group bank ag
# 884                erste group bank ag
# 885                erste group bank ag
# 886                erste group bank ag
# 887                erste group bank ag
# 888                erste group bank ag
# 889                erste group bank ag
# 890                erste group bank ag
# 891                erste group bank ag
# 892                erste group bank ag
# 893                erste group bank ag
# 894                erste group bank ag
# 895                erste group bank ag
# 896                erste group bank ag
# 897                erste group bank ag
# 898                erste group bank ag
# 899                erste group bank ag
# 900                erste group bank ag
# 901                erste group bank ag
# 902                erste group bank ag
# 903                erste group bank ag
# 904                erste group bank ag
# 905                erste group bank ag
# 906                erste group bank ag
# 907                erste group bank ag
# 908                erste group bank ag
# 909                erste group bank ag
# 910                erste group bank ag
# 911                erste group bank ag
# 912                erste group bank ag
# 913                erste group bank ag
# 914                erste group bank ag
# 915                erste group bank ag
# 916                erste group bank ag
# 917                erste group bank ag
# 918                erste group bank ag
# 919                erste group bank ag
# 920                erste group bank ag
# 921                erste group bank ag
# 922                erste group bank ag
# 923                erste group bank ag
# 924                erste group bank ag
# 925                erste group bank ag
# 926                erste group bank ag
# 927                erste group bank ag
# 928                erste group bank ag
# 929                erste group bank ag
# 930                erste group bank ag
# 931                erste group bank ag
# 932                erste group bank ag
# 933                erste group bank ag
# 934                erste group bank ag
# 935                erste group bank ag
# 936                erste group bank ag
# 937                erste group bank ag
# 938                erste group bank ag
# 939                erste group bank ag
# 940                erste group bank ag
# 941                erste group bank ag
# 942                erste group bank ag
# 943                erste group bank ag
# 944                erste group bank ag
# 945                erste group bank ag
# 946                erste group bank ag
# 947                erste group bank ag
# 948                erste group bank ag
# 949                erste group bank ag
# 950                erste group bank ag
# 951                erste group bank ag
# 952                erste group bank ag
# 953                erste group bank ag
# 954                erste group bank ag
# 955                erste group bank ag
# 956                erste group bank ag
# 957                erste group bank ag
# 958                erste group bank ag
# 959                erste group bank ag
# 960                erste group bank ag
# 961                erste group bank ag
# 962                erste group bank ag
# 963                erste group bank ag
# 964                erste group bank ag
# 965                erste group bank ag
# 966                erste group bank ag
# 967                erste group bank ag
# 968                erste group bank ag
# 969                erste group bank ag
# 970                erste group bank ag
# 971                erste group bank ag
# 972                erste group bank ag
# 973                erste group bank ag
# 974                erste group bank ag
# 975                erste group bank ag
# 976                erste group bank ag
# 977                erste group bank ag
# 978                erste group bank ag
# 979                erste group bank ag
# 980                erste group bank ag
# 981                erste group bank ag
# 982                erste group bank ag
# 983                erste group bank ag
# 984                erste group bank ag
# 985                erste group bank ag
# 986                erste group bank ag
# 987                erste group bank ag
# 988                erste group bank ag
# 989                erste group bank ag
# 990                erste group bank ag
# 991                erste group bank ag
# 992                erste group bank ag
# 993                erste group bank ag
# 994                erste group bank ag
# 995                erste group bank ag
# 996                erste group bank ag
# 997                erste group bank ag
# 998                erste group bank ag
# 999                erste group bank ag
# 1000               erste group bank ag
# 1001               erste group bank ag
# 1002               erste group bank ag
# 1003               erste group bank ag
# 1004               erste group bank ag
# 1005               erste group bank ag
# 1006               erste group bank ag
# 1007               erste group bank ag
# 1008               erste group bank ag
# 1009               erste group bank ag
# 1010               erste group bank ag
# 1011               erste group bank ag
# 1012               erste group bank ag
# 1013               erste group bank ag
# 1014               erste group bank ag
# 1015               erste group bank ag
# 1016               erste group bank ag
# 1017               erste group bank ag
# 1018               erste group bank ag
# 1019               erste group bank ag
# 1020               erste group bank ag
# 1021               erste group bank ag
# 1022               erste group bank ag
# 1023               erste group bank ag
# 1024               erste group bank ag
# 1025               erste group bank ag
# 1026               erste group bank ag
# 1027               erste group bank ag
# 1028               erste group bank ag
# 1029               erste group bank ag
# 1030               erste group bank ag
# 1031               erste group bank ag
# 1032               erste group bank ag
# 1033               erste group bank ag
# 1034               erste group bank ag
# 1035               erste group bank ag
# 1036               erste group bank ag
# 1037               erste group bank ag
# 1038               erste group bank ag
# 1039               erste group bank ag
# 1040               erste group bank ag
# 1041               erste group bank ag
# 1042               erste group bank ag
# 1043               erste group bank ag
# 1044               erste group bank ag
# 1045               erste group bank ag
# 1046               erste group bank ag
# 1047               erste group bank ag
# 1048               erste group bank ag
# 1049               erste group bank ag
# 1050               erste group bank ag
# 1051               erste group bank ag
# 1052               erste group bank ag
# 1053               erste group bank ag
# 1054               erste group bank ag
# 1055               erste group bank ag
# 1056               erste group bank ag
# 1057               erste group bank ag
# 1058               erste group bank ag
# 1059               erste group bank ag
# 1060               erste group bank ag
# 1061               erste group bank ag
# 1062               erste group bank ag
# 1063               erste group bank ag
# 1064               erste group bank ag
# 1065               erste group bank ag
# 1066               erste group bank ag
# 1067               erste group bank ag
# 1068               erste group bank ag
# 1069               erste group bank ag
# 1070               erste group bank ag
# 1071               erste group bank ag
# 1072               erste group bank ag
# 1073               erste group bank ag
# 1074               erste group bank ag
# 1075               erste group bank ag
# 1076               erste group bank ag
# 1077               erste group bank ag
# 1078               erste group bank ag
# 1079               erste group bank ag
# 1080               erste group bank ag
# 1081               erste group bank ag
# 1082               erste group bank ag
# 1083               erste group bank ag
# 1084               erste group bank ag
# 1085               erste group bank ag
# 1086               erste group bank ag
# 1087               erste group bank ag
# 1088               erste group bank ag
# 1089               erste group bank ag
# 1090               erste group bank ag
# 1091               erste group bank ag
# 1092               erste group bank ag
# 1093               erste group bank ag
# 1094               erste group bank ag
# 1095               erste group bank ag
# 1096               erste group bank ag
# 1097               erste group bank ag
# 1098               erste group bank ag
# 1099               erste group bank ag
# 1100               erste group bank ag
# 1101               erste group bank ag
# 1102               erste group bank ag
# 1103               erste group bank ag
# 1104               erste group bank ag
# 1105               erste group bank ag
# 1106               erste group bank ag
# 1107               erste group bank ag
# 1108               erste group bank ag
# 1109               erste group bank ag
# 1110               erste group bank ag
# 1111               erste group bank ag
# 1112               erste group bank ag
# 1113               erste group bank ag
# 1114               erste group bank ag
# 1115               erste group bank ag
# 1116               erste group bank ag
# 1117               erste group bank ag
# 1118               erste group bank ag
# 1119               erste group bank ag
# 1120                        andritz ag
# 1121                        andritz ag
# 1122                        andritz ag
# 1123                        andritz ag
# 1124                        andritz ag
# 1125                        andritz ag
# 1126                        andritz ag
# 1127                        andritz ag
# 1128                        andritz ag
# 1129                        andritz ag
# 1130                        andritz ag
# 1131                        andritz ag
# 1132                        andritz ag
# 1133                        andritz ag
# 1134                        andritz ag
# 1135                        andritz ag
# 1136                        andritz ag
# 1137                        andritz ag
# 1138                        andritz ag
# 1139                        andritz ag
# 1140                        andritz ag
# ...
# 1269                                             brazil      country    other
# 1270                                    isolde findenig       person    other
# 1271                                   veracel celulose        other    other
# 1272                                   simon bolivar ii        other    other
# 1273                                       forrest kerr       person    other
# 1274                                             panama      country    other
# 1450                                            austria      country    other
# 1451                                        andritz opp       person    other
# 1452                                            czechia      country    other
# 1453                                       josef körösi       person    other
# 1454                                production planning          dep    other
# 1455                                     russisft group          org    other
# 1456                                  thomas bachhofner       person    other
# 1457                            wolfgang amadeus mozart       person    other
# 1458                    sichuan shuncheng chemical corp          org    other
# 1459                             andritz iggesund tools       person    other
# 1460                                      ewos scotland       person    other
# 1461                                 hebei kaiyue group          org    other
# 1462                                dongkuk indus tries       person    other
# 1463                                     sabianci group          org    other
# 1464                       business process development        other    other
# 1465                                             brazil      country    other
# 1466             daewoo engineering construction co ltd          org    other
# 1467                              primedry steel yankee       person    other
# 1468  limak hydro electric power plant investment in...          gpe    other

# %% [markdown]
# As we notice at the dataframe above, the German Spacy model could not label even one single attribute out of 1.500 representing the three Austrian companies. We therefore assume that it is not expedient to use this model or models in other languages.

# %% [markdown]
# ### Use lists of first and last names from data.europa.eu to filter the attributes labeled as person

# %% [markdown]
# This next method was suggested by Ben Gronemann. Here, we use lists of first and last names from data.europe.eu in order to improve the accuracy of labeling persons. Additionally, we check for common words between the company and the attribute to ensure that attributes like for example 'zao raiffeisen' are not labeled as persons and we check for ' ' in the attribute, because a single word cannot not be a person. We assume that a person has to be named with first and last name.

# %%
# Function to update the label 'person' - FIRST AND LAST NAME
def update_label_first_and_last(row, first_names_list, last_names_list):
    attribute = str(row['attribute']) 
    company = str(row['company'])

    # Check for common words between company and attribute
    if any(company_part in attribute for company_part in company.split()):
        return 'other'
        
    # Set the booleans to False
    first_name = False
    last_name = False
    
    # Check if the attribute contains a first name
    for name in first_names_list:
        if name in attribute and ' ' in attribute:
            first_name = True
            break

    # Check if the attribute contains a last name
    for name in last_names_list:
        if name in attribute:
            last_name = True
            break

    if first_name and last_name:
        return row['label']  # Return the original label if a name is found

    return 'other'  # Label as 'other' if no name is found in attribute


# Function to update the label 'person' - FIRST NAME ONLY
def update_label_only_first(row, names_list):
    attribute = str(row['attribute'])
    company = str(row['company'])

    # Check for common words between company and attribute
    if any(company_part in attribute for company_part in company.split()):
        return 'other'

    # Check for names in attribute
    for name in names_list:
        if str(name).lower() in attribute.lower() and ' ' in attribute:
            return row['label']  # Return the original label if a name is found
    return 'other'  # Label as 'other' if no name is found in attribute


# Function to extract person names from the attribute
NER = spacy.load("en_core_web_trf")
def extract_person(attribute):
    doc = NER(attribute)
    person_parts = [ent.text for ent in doc.ents]
    return ' '.join(person_parts)


def improve_person_labeling(labeled_network_df, onlyfirst_or_firstandlast = 'onlyfirst'):
    
    # Read the csv files with first and last names
    first_names = pd.read_csv('Liste der Vornamen-1.csv')
    last_names = pd.read_csv('Liste der Nachnamen-2.csv')

    # Change the 'prenom'/'patronyme' column to lowercase
    first_names.loc[:, 'prenom'] = first_names['prenom'].str.lower()
    last_names.loc[:, 'patronyme'] = last_names['patronyme'].str.lower()

    # Filter the dataframes
    first_names_filtered = first_names[first_names['sum'] > 350]
    last_names_filtered = last_names[last_names['count'] > 100]

    # Convert the names dataframes to lists
    first_names_list = first_names_filtered['prenom'].tolist()
    last_names_list = last_names_filtered['patronyme'].tolist()

    # Split the original network dataframe into two parts
    network_person = labeled_network_df[labeled_network_df['label'] == 'person']
    network_without_person = labeled_network_df[labeled_network_df['label'] != 'person']

    # Update the 'attribute' column by applying the function to extract persons
    network_person = network_person.copy()  # Create a copy of the slice to ensure it's independent from the original dataframe (suggested by Warning message)
    network_person.loc[network_person.index, 'attribute'] = network_person['attribute'].apply(extract_person)

    if onlyfirst_or_firstandlast == 'firstandlast':
        # Apply the function to update the labels of the person-df
        network_person.loc[:, 'label'] = network_person.apply(update_label_first_and_last, axis=1, args=(first_names_list, last_names_list,))

    elif onlyfirst_or_firstandlast == 'onlyfirst':
        # Apply the function to update the labels of the person-df
        network_person.loc[:, 'label'] = network_person.apply(update_label_only_first, axis=1, args=(first_names_list,))

    else:
        return 'Please enter "firstandlast" or "onlyfirst" as the second argument'

    # Put the two dataframes together
    updated_df = pd.concat([network_person, network_without_person], ignore_index=True)

    return updated_df

# %% [markdown]
# After testing the function with different parameters on the testfile, we concluded that the best result is delivered by using both, the first (count > 350) and the last (count > 100) name.

# %%
# Apply the function on the testfile to check the accuracy
testfile_updated = improve_person_labeling(testfile_2011, 'firstandlast')
print_full(testfile_updated)
# Out:
#                                company  \
# 0     raiffeisen bank international ag
# 1     raiffeisen bank international ag
# 2     raiffeisen bank international ag
# 3     raiffeisen bank international ag
# 4     raiffeisen bank international ag
# 5     raiffeisen bank international ag
# 6     raiffeisen bank international ag
# 7     raiffeisen bank international ag
# 8     raiffeisen bank international ag
# 9     raiffeisen bank international ag
# 10    raiffeisen bank international ag
# 11    raiffeisen bank international ag
# 12    raiffeisen bank international ag
# 13    raiffeisen bank international ag
# 14    raiffeisen bank international ag
# 15    raiffeisen bank international ag
# 16    raiffeisen bank international ag
# 17    raiffeisen bank international ag
# 18    raiffeisen bank international ag
# 19    raiffeisen bank international ag
# 20    raiffeisen bank international ag
# 21    raiffeisen bank international ag
# 22    raiffeisen bank international ag
# 23    raiffeisen bank international ag
# 24    raiffeisen bank international ag
# 25    raiffeisen bank international ag
# 26    raiffeisen bank international ag
# 27    raiffeisen bank international ag
# 28    raiffeisen bank international ag
# 29    raiffeisen bank international ag
# 30    raiffeisen bank international ag
# 31    raiffeisen bank international ag
# 32    raiffeisen bank international ag
# 33    raiffeisen bank international ag
# 34    raiffeisen bank international ag
# 35    raiffeisen bank international ag
# 36    raiffeisen bank international ag
# 37    raiffeisen bank international ag
# 38    raiffeisen bank international ag
# 39    raiffeisen bank international ag
# 40                 erste group bank ag
# 41                 erste group bank ag
# 42                 erste group bank ag
# 43                 erste group bank ag
# 44                 erste group bank ag
# 45                 erste group bank ag
# 46                 erste group bank ag
# 47                 erste group bank ag
# 48                 erste group bank ag
# 49                 erste group bank ag
# 50                 erste group bank ag
# 51                 erste group bank ag
# 52                 erste group bank ag
# 53                 erste group bank ag
# 54                 erste group bank ag
# 55                 erste group bank ag
# 56                 erste group bank ag
# 57                 erste group bank ag
# 58                 erste group bank ag
# 59                 erste group bank ag
# 60                 erste group bank ag
# 61                 erste group bank ag
# 62                 erste group bank ag
# 63                 erste group bank ag
# 64                 erste group bank ag
# 65                 erste group bank ag
# 66                 erste group bank ag
# 67                 erste group bank ag
# 68                 erste group bank ag
# 69                 erste group bank ag
# 70                 erste group bank ag
# 71                 erste group bank ag
# 72                 erste group bank ag
# 73                 erste group bank ag
# 74                 erste group bank ag
# 75                 erste group bank ag
# 76                 erste group bank ag
# 77                 erste group bank ag
# 78                 erste group bank ag
# 79                 erste group bank ag
# 80                 erste group bank ag
# 81                 erste group bank ag
# 82                 erste group bank ag
# 83                 erste group bank ag
# 84                 erste group bank ag
# 85                 erste group bank ag
# 86                 erste group bank ag
# 87                 erste group bank ag
# 88                 erste group bank ag
# 89                 erste group bank ag
# 90                 erste group bank ag
# 91                 erste group bank ag
# 92                 erste group bank ag
# 93                 erste group bank ag
# 94                 erste group bank ag
# 95                 erste group bank ag
# 96                 erste group bank ag
# 97                 erste group bank ag
# 98                 erste group bank ag
# 99                 erste group bank ag
# 100                erste group bank ag
# 101                erste group bank ag
# 102                erste group bank ag
# 103                erste group bank ag
# 104                erste group bank ag
# 105                erste group bank ag
# 106                erste group bank ag
# 107                erste group bank ag
# 108                erste group bank ag
# 109                erste group bank ag
# 110                erste group bank ag
# 111                erste group bank ag
# 112                erste group bank ag
# 113                erste group bank ag
# 114                erste group bank ag
# 115                erste group bank ag
# 116                erste group bank ag
# 117                erste group bank ag
# 118                erste group bank ag
# 119                erste group bank ag
# 120                erste group bank ag
# 121                erste group bank ag
# 122                erste group bank ag
# 123                erste group bank ag
# 124                erste group bank ag
# 125                erste group bank ag
# 126                erste group bank ag
# 127                erste group bank ag
# 128                erste group bank ag
# 129                erste group bank ag
# 130                erste group bank ag
# 131                erste group bank ag
# 132                erste group bank ag
# 133                erste group bank ag
# 134                erste group bank ag
# 135                erste group bank ag
# 136                erste group bank ag
# 137                erste group bank ag
# 138                erste group bank ag
# 139                erste group bank ag
# 140                erste group bank ag
# 141                erste group bank ag
# 142                erste group bank ag
# 143                erste group bank ag
# 144                erste group bank ag
# 145                erste group bank ag
# 146                erste group bank ag
# 147                erste group bank ag
# 148                         andritz ag
# 149                         andritz ag
# 150                         andritz ag
# 151                         andritz ag
# 152                         andritz ag
# 153                         andritz ag
# 154                         andritz ag
# 155                         andritz ag
# 156                         andritz ag
# 157                         andritz ag
# 158                         andritz ag
# 159                         andritz ag
# 160                         andritz ag
# 161                         andritz ag
# 162                         andritz ag
# 163                         andritz ag
# 164                         andritz ag
# 165                         andritz ag
# 166                         andritz ag
# 167                         andritz ag
# 168                         andritz ag
# 169                         andritz ag
# 170                         andritz ag
# 171                         andritz ag
# 172                         andritz ag
# 173                         andritz ag
# 174                         andritz ag
# 175                         andritz ag
# 176                         andritz ag
# 177                         andritz ag
# 178                         andritz ag
# 179                         andritz ag
# 180                         andritz ag
# 181                         andritz ag
# 182                         andritz ag
# 183                         andritz ag
# 184                         andritz ag
# 689                erste group bank ag
# 690                erste group bank ag
# 691                erste group bank ag
# 692                erste group bank ag
# 693                erste group bank ag
# 694                erste group bank ag
# 695                erste group bank ag
# 696                erste group bank ag
# 697                erste group bank ag
# 698                erste group bank ag
# 699                erste group bank ag
# 700                erste group bank ag
# 701                erste group bank ag
# 702                erste group bank ag
# 703                erste group bank ag
# 704                erste group bank ag
# 705                erste group bank ag
# 706                erste group bank ag
# 707                erste group bank ag
# 708                erste group bank ag
# 709                erste group bank ag
# 710                erste group bank ag
# 711                erste group bank ag
# 712                erste group bank ag
# 713                erste group bank ag
# 714                erste group bank ag
# 715                erste group bank ag
# 716                erste group bank ag
# 717                erste group bank ag
# 718                erste group bank ag
# 719                erste group bank ag
# 720                erste group bank ag
# 721                erste group bank ag
# 722                erste group bank ag
# 723                erste group bank ag
# 724                erste group bank ag
# 725                erste group bank ag
# 726                erste group bank ag
# 727                erste group bank ag
# 728                erste group bank ag
# 729                erste group bank ag
# 730                erste group bank ag
# 731                erste group bank ag
# 732                erste group bank ag
# 733                erste group bank ag
# 734                erste group bank ag
# 735                erste group bank ag
# 736                erste group bank ag
# 737                erste group bank ag
# 738                erste group bank ag
# 739                erste group bank ag
# 740                erste group bank ag
# 741                erste group bank ag
# 742                erste group bank ag
# 743                erste group bank ag
# 744                erste group bank ag
# 745                erste group bank ag
# 746                erste group bank ag
# 747                erste group bank ag
# 748                erste group bank ag
# 749                erste group bank ag
# 750                erste group bank ag
# 751                erste group bank ag
# 752                erste group bank ag
# 753                erste group bank ag
# 754                erste group bank ag
# 755                erste group bank ag
# 756                erste group bank ag
# 757                erste group bank ag
# 758                erste group bank ag
# 759                erste group bank ag
# 760                erste group bank ag
# 761                erste group bank ag
# 762                erste group bank ag
# 763                erste group bank ag
# 764                erste group bank ag
# 765                erste group bank ag
# 766                erste group bank ag
# 767                erste group bank ag
# 768                erste group bank ag
# 769                erste group bank ag
# 770                erste group bank ag
# 771                erste group bank ag
# 772                erste group bank ag
# 773                erste group bank ag
# 774                erste group bank ag
# 775                erste group bank ag
# 776                erste group bank ag
# 777                erste group bank ag
# 778                erste group bank ag
# 779                erste group bank ag
# 780                erste group bank ag
# 781                erste group bank ag
# 782                erste group bank ag
# 783                erste group bank ag
# 784                erste group bank ag
# 785                erste group bank ag
# 786                erste group bank ag
# 787                erste group bank ag
# 788                erste group bank ag
# 789                erste group bank ag
# 790                erste group bank ag
# 791                erste group bank ag
# 792                erste group bank ag
# 793                erste group bank ag
# 794                erste group bank ag
# 795                erste group bank ag
# 796                erste group bank ag
# 797                erste group bank ag
# 798                erste group bank ag
# 799                erste group bank ag
# 800                erste group bank ag
# 801                erste group bank ag
# 802                erste group bank ag
# 803                erste group bank ag
# 804                erste group bank ag
# 805                erste group bank ag
# 806                erste group bank ag
# 807                erste group bank ag
# 808                erste group bank ag
# 809                erste group bank ag
# 810                erste group bank ag
# 811                erste group bank ag
# 812                erste group bank ag
# 813                erste group bank ag
# 814                erste group bank ag
# 815                erste group bank ag
# 816                erste group bank ag
# 817                erste group bank ag
# 818                erste group bank ag
# 819                erste group bank ag
# 820                erste group bank ag
# 821                erste group bank ag
# 822                erste group bank ag
# 823                erste group bank ag
# 824                erste group bank ag
# 825                erste group bank ag
# 826                erste group bank ag
# 827                erste group bank ag
# 828                erste group bank ag
# 829                erste group bank ag
# 830                erste group bank ag
# 831                erste group bank ag
# 832                erste group bank ag
# 833                erste group bank ag
# 834                erste group bank ag
# 835                erste group bank ag
# 836                erste group bank ag
# 837                erste group bank ag
# 838                erste group bank ag
# 839                erste group bank ag
# 840                erste group bank ag
# 841                erste group bank ag
# 842                erste group bank ag
# 843                erste group bank ag
# 844                erste group bank ag
# 845                erste group bank ag
# 846                erste group bank ag
# 847                erste group bank ag
# 848                erste group bank ag
# 849                erste group bank ag
# 850                erste group bank ag
# 851                erste group bank ag
# 852                erste group bank ag
# 853                erste group bank ag
# 854                erste group bank ag
# 855                erste group bank ag
# 856                erste group bank ag
# 857                erste group bank ag
# 858                erste group bank ag
# 859                erste group bank ag
# 860                erste group bank ag
# 861                erste group bank ag
# 862                erste group bank ag
# 863                erste group bank ag
# 864                erste group bank ag
# 865                erste group bank ag
# 866                erste group bank ag
# 867                erste group bank ag
# 868                erste group bank ag
# 869                erste group bank ag
# 870                erste group bank ag
# 871                erste group bank ag
# 872                erste group bank ag
# 873                erste group bank ag
# 874                erste group bank ag
# 875                erste group bank ag
# 876                erste group bank ag
# 877                erste group bank ag
# 878                erste group bank ag
# 879                erste group bank ag
# 880                erste group bank ag
# 881                erste group bank ag
# 882                erste group bank ag
# 883                erste group bank ag
# 884                erste group bank ag
# 885                erste group bank ag
# 886                erste group bank ag
# 887                erste group bank ag
# 888                erste group bank ag
# 889                erste group bank ag
# 890                erste group bank ag
# 891                erste group bank ag
# 892                erste group bank ag
# 893                erste group bank ag
# 894                erste group bank ag
# 895                erste group bank ag
# 896                erste group bank ag
# 897                erste group bank ag
# 898                erste group bank ag
# 899                erste group bank ag
# 900                erste group bank ag
# 901                erste group bank ag
# 902                erste group bank ag
# 903                erste group bank ag
# 904                erste group bank ag
# 905                erste group bank ag
# 906                erste group bank ag
# 907                erste group bank ag
# 908                erste group bank ag
# 909                erste group bank ag
# 910                erste group bank ag
# 911                erste group bank ag
# 912                erste group bank ag
# 913                erste group bank ag
# 914                erste group bank ag
# 915                erste group bank ag
# 916                erste group bank ag
# 917                erste group bank ag
# 918                erste group bank ag
# 919                erste group bank ag
# 920                erste group bank ag
# 921                erste group bank ag
# 922                erste group bank ag
# 923                erste group bank ag
# 924                erste group bank ag
# 925                erste group bank ag
# 926                erste group bank ag
# 927                erste group bank ag
# 928                erste group bank ag
# 929                erste group bank ag
# 930                erste group bank ag
# 931                erste group bank ag
# 932                erste group bank ag
# 933                erste group bank ag
# 934                erste group bank ag
# 935                erste group bank ag
# 936                erste group bank ag
# 937                erste group bank ag
# 938                erste group bank ag
# 939                erste group bank ag
# 940                erste group bank ag
# 941                erste group bank ag
# 942                erste group bank ag
# 943                erste group bank ag
# 944                erste group bank ag
# 945                erste group bank ag
# 946                erste group bank ag
# 947                erste group bank ag
# 948                erste group bank ag
# 949                erste group bank ag
# 950                erste group bank ag
# 951                erste group bank ag
# 952                erste group bank ag
# 953                erste group bank ag
# 954                erste group bank ag
# 955                erste group bank ag
# 956                erste group bank ag
# 957                erste group bank ag
# 958                erste group bank ag
# 959                erste group bank ag
# 960                erste group bank ag
# 961                erste group bank ag
# 962                erste group bank ag
# 963                erste group bank ag
# 964                erste group bank ag
# 965                erste group bank ag
# 966                erste group bank ag
# 967                erste group bank ag
# 968                erste group bank ag
# 969                erste group bank ag
# 970                erste group bank ag
# 971                erste group bank ag
# 972                erste group bank ag
# 973                erste group bank ag
# 974                erste group bank ag
# 975                erste group bank ag
# 976                erste group bank ag
# 977                erste group bank ag
# 978                erste group bank ag
# 979                erste group bank ag
# 980                erste group bank ag
# 981                erste group bank ag
# 982                erste group bank ag
# 983                erste group bank ag
# 984                erste group bank ag
# 985                erste group bank ag
# 986                erste group bank ag
# 987                erste group bank ag
# 988                erste group bank ag
# 989                erste group bank ag
# 990                erste group bank ag
# 991                erste group bank ag
# 992                erste group bank ag
# 993                erste group bank ag
# 994                erste group bank ag
# 995                erste group bank ag
# 996                erste group bank ag
# 997                erste group bank ag
# 998                erste group bank ag
# 999                erste group bank ag
# 1000               erste group bank ag
# 1001               erste group bank ag
# 1002               erste group bank ag
# 1003               erste group bank ag
# 1004               erste group bank ag
# 1005               erste group bank ag
# 1006               erste group bank ag
# 1007               erste group bank ag
# 1008               erste group bank ag
# 1009               erste group bank ag
# 1010               erste group bank ag
# 1011               erste group bank ag
# 1012               erste group bank ag
# 1013               erste group bank ag
# 1014               erste group bank ag
# 1015               erste group bank ag
# 1016               erste group bank ag
# 1017               erste group bank ag
# 1018               erste group bank ag
# 1019               erste group bank ag
# 1020               erste group bank ag
# 1021               erste group bank ag
# 1022               erste group bank ag
# 1023               erste group bank ag
# 1024               erste group bank ag
# 1025               erste group bank ag
# 1026               erste group bank ag
# 1027               erste group bank ag
# 1028               erste group bank ag
# 1029               erste group bank ag
# 1030               erste group bank ag
# 1031               erste group bank ag
# 1032               erste group bank ag
# 1033               erste group bank ag
# 1034               erste group bank ag
# 1035               erste group bank ag
# 1036               erste group bank ag
# 1037               erste group bank ag
# 1038               erste group bank ag
# 1039               erste group bank ag
# 1040               erste group bank ag
# 1041               erste group bank ag
# 1042               erste group bank ag
# 1043               erste group bank ag
# 1044               erste group bank ag
# 1045               erste group bank ag
# 1046               erste group bank ag
# 1047               erste group bank ag
# 1048               erste group bank ag
# 1049               erste group bank ag
# 1050               erste group bank ag
# 1051               erste group bank ag
# 1052               erste group bank ag
# 1053               erste group bank ag
# 1054               erste group bank ag
# 1055               erste group bank ag
# 1056               erste group bank ag
# 1057               erste group bank ag
# 1058               erste group bank ag
# 1059               erste group bank ag
# 1060               erste group bank ag
# 1061               erste group bank ag
# 1062               erste group bank ag
# 1063               erste group bank ag
# 1064               erste group bank ag
# 1065               erste group bank ag
# 1066               erste group bank ag
# 1067               erste group bank ag
# 1068               erste group bank ag
# 1069               erste group bank ag
# 1070               erste group bank ag
# 1071               erste group bank ag
# 1072               erste group bank ag
# 1073               erste group bank ag
# 1074               erste group bank ag
# 1075               erste group bank ag
# 1076               erste group bank ag
# 1077               erste group bank ag
# 1078               erste group bank ag
# 1079               erste group bank ag
# 1080               erste group bank ag
# 1081               erste group bank ag
# 1082               erste group bank ag
# 1083               erste group bank ag
# 1084               erste group bank ag
# 1085               erste group bank ag
# 1086               erste group bank ag
# 1087               erste group bank ag
# 1088               erste group bank ag
# 1089               erste group bank ag
# 1090               erste group bank ag
# 1091               erste group bank ag
# 1092               erste group bank ag
# 1093               erste group bank ag
# 1094               erste group bank ag
# 1095               erste group bank ag
# 1096               erste group bank ag
# 1097               erste group bank ag
# 1098               erste group bank ag
# 1099               erste group bank ag
# 1100               erste group bank ag
# 1101               erste group bank ag
# 1102               erste group bank ag
# 1103               erste group bank ag
# 1104               erste group bank ag
# 1105               erste group bank ag
# 1106               erste group bank ag
# 1107               erste group bank ag
# 1108               erste group bank ag
# 1109               erste group bank ag
# 1110               erste group bank ag
# 1111               erste group bank ag
# 1112               erste group bank ag
# 1113               erste group bank ag
# 1114               erste group bank ag
# 1115               erste group bank ag
# 1116               erste group bank ag
# 1117               erste group bank ag
# 1118               erste group bank ag
# 1119               erste group bank ag
# 1120               erste group bank ag
# 1121               erste group bank ag
# 1122               erste group bank ag
# 1123               erste group bank ag
# 1124               erste group bank ag
# 1125               erste group bank ag
# 1126               erste group bank ag
# 1127               erste group bank ag
# 1128               erste group bank ag
# 1129               erste group bank ag
# 1130               erste group bank ag
# 1131               erste group bank ag
# 1132               erste group bank ag
# 1133               erste group bank ag
# 1134               erste group bank ag
# 1135               erste group bank ag
# 1136               erste group bank ag
# 1137               erste group bank ag
# 1138               erste group bank ag
# 1139               erste group bank ag
# 1140               erste group bank ag
# ...
# 1269                                            austria      country    other
# 1270                                  fiber preparation        other    other
# 1271                                            germany      country    other
# 1272                                        switzerland      country    other
# 1273                  best european inves tor relations         norp    other
# 1274                           andritz sproutbauer gmbh          org    other
# 1275                               andritz hydro inepar          org    other
# 1276                                    forces motrices        other    other
# 1277              posco engineering construction co ltd          org    other
# 1278                                       south africa      country    other
# 1279                                           joutseno         city    other
# 1280                                       andritz feed        other    other
# 1281                                      norte energia        other    other
# 1282                                         azerbaijan      country    other
# 1283                      pohang stainless steel co ltd          org    other
# 1284                                          argentina      country    other
# 1285                                            germany      country    other
# 1286                            vattenfall europe power          org    other
# 1287                                 guangdong province          gpe    other
# 1288                                  central rent gold        other    other
# 1289                                         pulp paper        other    other
# 1290                                       biomar group          org    other
# 1291                                            uruguay      country    other
# 1292                                            wetzlar         city    other
# 1293                                          hong kong      country    other
# 1294                        capital group international          org    other
# 1295                                              italy      country    other
# 1296                          secondary public offering        other    other
# 1297                                          mayrhofen         city    other
# 1298                                            sandown         city    other
# 1299                                         costa rica      country    other
# 1300                                        oberbank ag          org    other
# 1301                                      andritz hydro          org    other
# 1302                                        jf holdings          org    other
# 1303                                      viennstock ex          gpe    other
# 1304                                        fray bentos        other    other
# 1305                                              chile      country    other
# 1306                                        switzerland      country    other
# 1307                                      triplea sales          dep    other
# 1308                                             munich         city    other
# 1309                                          wolf gang        other    other
# 1310                                             dallas         city    other
# 1311                                             brazil      country    other
# 1312                                   veracel celulose        other    other
# 1313                                   simon bolivar ii        other    other
# 1314                                             panama      country    other
# 1315                               usa confidential new          org    other
# 1316                                        philippines      country    other
# 1317                                            chicago         city    other
# 1318                                         hydro unit        other    other
# 1319                                 andritz hydro gmbh          org    other
# 1320                                             russia      country    other
# 1321            kraftwerke hinterrhein ag refurbishment          org    other
# 1322                                            germany      country    other
# 1323                                pulp drying systems        other    other
# 1324                                genericon pharmgmbh          org    other
# 1325                                      nisshin steel          org    other
# 1326                                          ment gmbh          org    other
# 1327                                              japan      country    other
# 1328                                       ludwigshafen         city    other
# 1329                                  riau andalan pulp          org    other
# 1330                                              japan      country    other
# 1331                                             foshan         city    other
# 1332                                             lugano         city    other
# 1333                     rma rheingau gmbh co kg supply          org    other
# 1334                                           thailand      country    other
# 1335                                    voestalpine mce          org    other
# 1336                                            türkiye      country    other
# 1337                                         rwe innogy        other    other
# 1338                                            algeria      country    other
# 1339                                            ecuador      country    other
# 1340                                        knittelfeld         city    other
# 1341                                        furen group          org    other
# 1342                               altagas income trust          org    other
# 1343                                           thailand      country    other
# 1344                                           valdosta         city    other
# 1345                                         strabag ag          org    other
# 1346                                            toronto         city    other
# 1347                                            chengdu         city    other
# 1348                                  feed biofuel unit        other    other
# 1349                                   french nsc group          org    other
# 1350                                    one stee co ltd          org    other
# 1351                                          rio tinto         city    other
# 1352                              petro chemical co ltd          org    other
# 1353                                            miba ag          org    other
# 1354                                           slovenia      country    other
# 1355                                     scottish power         norp    other
# 1356                                      russijsc soda          org    other
# 1357                               oji papéis especiais        other    other
# 1358                                            glasgow         city    other
# 1359                         mechanical pulping systems        other    other
# 1360                                            gmbh co          org    other
# 1361                                             co ltd          org    other
# 1362           usa east texas electricity refurbishment          gpe    other
# 1363                                          sheffield         city    other
# 1364              jsc territorial generating company no          org    other
# 1365                        russillc pulp invest tissue          org    other
# 1366                                     rheinmetall ag          org    other
# 1367                                           aus tria        other    other
# 1368                           pulp paper business area        other    other
# 1369                         thyssen krupp steel europe          org    other
# 1370                                            austria      country    other
# 1371                                            austria      country    other
# 1372              austriverbund hydro power ag revision          org    other
# 1373                                          tennessee         city    other
# 1374                              vyborgskaja cellulosa        other    other
# 1375                              sao tome and principe      country    other
# 1376                               polski asphalt spzoo          org    other
# 1377                                 andritz pulp paper          org    other
# 1378                                             hainan         city    other
# 1379                                    pulp paper unit        other    other
# 1380                                          mendre ii        other    other
# 1381                                       aceri nox sa          org    other
# 1382                                     united kingdom      country    other
# 1383                               nonwovens rmobonding        other    other
# 1384                                          frankfurt          gpe    other
# 1385                                             bremen         city    other
# 1386                                             brazil      country    other
# 1387                                             vyborg         city    other
# 1388                                              china      country    other
# 1389                                     hydro tasmania          gpe    other
# 1390                                            agiv ag          org    other
# 1391                                     gmbh extension        other    other
# 1392                                  mondi services ag          org    other
# 1393                                             france      country    other
# 1394                         uk iggesund paperboard ltd          org    other
# 1395                        andritz capital market days        other    other
# 1396                                   german rwe group          org    other
# 1397                                           shanghai         city    other
# 1398                                             sweden      country    other
# 1399                           corporate communications          dep    other
# 1400                                        três lagoas        other    other
# 1401                                  technical college        other    other
# 1402                               aee austrigmbh co kg        other    other
# 1403                            initial public offering        other    other
# 1404                                             boston         city    other
# 1405                                          sau start        other    other
# 1406                                              china      country    other
# 1407                                   rasselstein gmbh          org    other
# 1408                                            america         city    other
# 1409                                              india      country    other
# 1410                                       liquid funds        other    other
# 1411                                         budds farm          org    other
# 1412                                          singapore      country    other
# 1413                            andritz sproutbauer inc          org    other
# 1414                                         andritz ag          org    other
# 1415                       computational fluid dynamics        other    other
# 1416                                           malaysia      country    other
# 1417                                            finland      country    other
# 1418                                              tokyo         city    other
# 1419             thyssenkrupp acciai speciali terni spa          org    other
# 1420                                         verbund ag          org    other
# 1421                                            foz tua        other    other
# 1422               usa upper occoquan service authority          org    other
# 1423                                        metals unit        other    other
# 1424                                             vienna         city    other
# 1425               british columbihydro power authority          org    other
# 1426                                hypo oberösterreich        other    other
# 1427                                      va tech hydro        other    other
# 1428                                 gmbh modernization          org    other
# 1429                                 hemicycle controls        other    other
# 1430                        chinwuhan iron and steel co          org    other
# 1431                                 dongkuk industries          gpe    other
# 1432                                          indonesia      country    other
# 1433                                           scotland         city    other
# 1434                                              spain      country    other
# 1435                                            hungary      country    other
# 1436                                            austria      country    other
# 1437                                           slovakia      country    other
# 1438                                     united kingdom      country    other
# 1439                                              spain      country    other
# 1440                     chinhebei changtai industry co          org    other
# 1441                                            belgium      country    other
# 1442                                           koszalin         city    other
# 1443                                     berenberg bank          org    other
# 1444                                capital expenditure        other    other
# 1445                                       johannesburg         city    other
# 1446                               tenagnasional berhad        other    other
# 1447                            pulp and paper machines        other    other
# 1448                                   schaeffler group          org    other
# 1449                                             norway      country    other
# 1450                                            beijing         city    other
# 1451                         andritz investor relations          org    other
# 1452                                              milan         city    other
# 1453                                    capital systems        other    other
# 1454                             mondi steti evaporator          org    other
# 1455                                      united states      country    other
# 1456                                            germany      country    other
# 1457                                  abfall service ag          org    other
# 1458                                            austria      country    other
# 1459                                            czechia      country    other
# 1460                                production planning          dep    other
# 1461                                     russisft group          org    other
# 1462                    sichuan shuncheng chemical corp          org    other
# 1463                                 hebei kaiyue group          org    other
# 1464                                     sabianci group          org    other
# 1465                       business process development        other    other
# 1466                                             brazil      country    other
# 1467             daewoo engineering construction co ltd          org    other
# 1468  limak hydro electric power plant investment in...          gpe    other

# %%
# Apply the function on all network dataframes to update the 'person' labels
labeled_2011_updated = improve_person_labeling(labeled_2011, 'firstandlast')
labeled_2013_updated = improve_person_labeling(labeled_2013, 'firstandlast')
labeled_2016_updated = improve_person_labeling(labeled_2016, 'firstandlast')
labeled_2022_updated = improve_person_labeling(labeled_2022, 'firstandlast')

# %%
# Function to manually label some attributes right
def update_labels_manually(labeled_network_df):

    # Define the mapping from attribute to new label
    label_mapping = {
        'são paulo': 'city',
        'monte carlo': 'gpe',
        'jp morgan': 'org',
        'morgan stanley': 'org',
        'eli lilly': 'org',
        'dow jones': 'other',
        'boehringer ingelheim': 'other',
        'imd lausanne': 'dep',
        'são paulo brl': 'other',
        'deloitte touche': 'other',
        'akzo nobel': 'other',
        'srl milan': 'org',
        'frost sullivan': 'other',
        'euro pean': 'gpe',
        'lehman brors': 'org',
        'sl madrid': 'other',
        'lenz staehelin': 'org', 
        'kepler cheuvreux': 'org',
        'ihs markit': 'org',
        'georg fischer': 'org',
        'barry callebaut': 'org',
        'chartder vielfalt': 'other',
        'arthur anderson': 'org'
    }

    # Apply the mapping to the dataframe
    for attribute, new_label in label_mapping.items():
        labeled_network_df.loc[labeled_network_df['attribute'] == attribute, 'label'] = new_label

    return labeled_network_df

# %%
# Apply the function on all network dataframes
labeled_2011_updated = update_labels_manually(labeled_2011_updated)
labeled_2013_updated = update_labels_manually(labeled_2013_updated)
labeled_2016_updated = update_labels_manually(labeled_2016_updated)
labeled_2022_updated = update_labels_manually(labeled_2022_updated)

# %% [markdown]
# # Load and Preprocess the CIQ data

# %%
import numpy as np

# Read the 2023 CIQ_data
df_ciq = pd.read_csv('../Files/CIQ_data_DS_LAB.csv')

# Choose the relevant columns and change them to lowercase
df_ciq = df_ciq[['Name', 'IQ_PRIMARY_INDUSTRY', 'IQ_EXCHANGE', 'IQ_CITY', 'IQ_COUNTRY_NAME', 'IQ_EMPLOYEES', 'IQ_CEO_NAME', 'IQ_CFO_NAME', 'IQ_SP_LC_LT', 
                'Supplier1', 'Supplier2', 'Supplier3', 'Supplier4', 'Supplier5', 'Supplier6', 'Supplier7', 'Supplier8', 'Supplier9', 'Supplier10',
                'customer1', 'customer2', 'customer3', 'customer4', 'customer5', 'customer6', 'customer7', 'customer8', 'customer9', 'customer10',
                'bm1', 'bm2', 'bm3', 'bm4', 'bm5', 'bm6', 'bm7', 'bm8', 'bm9', 'bm10']].apply(lambda x: x.str.lower())

# Drop rows with a specific 'Name'
df_ciq = df_ciq[~df_ciq['Name'].isin(['Nordea Bank Abp', 'Dassault Aviation SA', '1 - 600 of 600'])]

# Converting 'Board Member' entries in 'bm2' to NaN
df_ciq['bm2'] = df_ciq['bm2'].replace('Board Member', np.nan)

# Rename the headers
df_ciq.rename(columns={'IQ_PRIMARY_INDUSTRY': 'industry'}, inplace=True)
df_ciq.rename(columns={'IQ_EXCHANGE': 'exchange'}, inplace=True)
df_ciq.rename(columns={'IQ_CITY': 'home_city'}, inplace=True)
df_ciq.rename(columns={'IQ_COUNTRY_NAME': 'home_country'}, inplace=True)
df_ciq.rename(columns={'IQ_EMPLOYEES': 'employees'}, inplace=True)
df_ciq.rename(columns={'IQ_CEO_NAME': 'ceo'}, inplace=True)
df_ciq.rename(columns={'IQ_CFO_NAME': 'cfo'}, inplace=True)
df_ciq.rename(columns={'IQ_SP_LC_LT': 'rating'}, inplace=True)

# Change the column headers of the company_df to lowercase
df_ciq.columns = [col.lower() for col in df_ciq.columns]

# Replace '(invalid identifier)' with NaN
df_ciq = df_ciq.replace(to_replace='(invalid identifier)', value=np.nan)

# Replace the values in the 'industry' column
df_ciq['industry'] = df_ciq['industry'].replace({'apparel, accessories and luxury goods': 'apparel accessories and luxury goods',
                                                        'multi-line insurance': 'multi_line insurance'})

# Person and org columns to remove commas from
columns_to_remove_commas = ['ceo', 'cfo', 'supplier1', 'supplier2', 'supplier3', 'supplier4', 'supplier5', 'supplier6', 'supplier7', 'supplier8', 'supplier9', 'supplier10',
                            'customer1', 'customer2', 'customer3', 'customer4', 'customer5', 'customer6', 'customer7', 'customer8', 'customer9', 'customer10',
                            'bm1', 'bm2', 'bm3', 'bm4', 'bm5', 'bm6', 'bm7', 'bm8', 'bm9', 'bm10']

# Apply the replace function to each specified column
for col in columns_to_remove_commas:
    df_ciq[col] = df_ciq[col].str.replace(',', '')

# %%
def convert_ratings_to_numeric(dataframe, column_name, conversion_dict):

    # Check if the column exists in the dataframe
    if column_name not in dataframe.columns:
        raise ValueError(f"The column {column_name} does not exist in the dataframe.")
    
    # Replace the ratings using the conversion dictionary
    dataframe[column_name] = dataframe[column_name].map(conversion_dict)
    
    # Handle any ratings that could not be converted (if any)
    if dataframe[column_name].isnull().any():
        missing_ratings = dataframe[column_name].isnull().sum()
        print(f"Warning: {missing_ratings} ratings could not be converted and are set as NaN.")
    
    return dataframe

conversion_dict = {
    'aaa': 100,
    'aa+': 95,
    'aa': 90,
    'aa-': 85,
    'a+': 80,
    'a': 75,
    'a-': 70,
    'bbb+': 65,
    'bbb': 60,
    'bbb-': 55,
    'bb+': 50,
    'bb': 45,
    'bb-': 40,
    'b+': 35,
    'b': 30,
    'b-': 25,
    'ccc+': 20,
    'ccc': 20,
    'ccc-': 20,
    'cc': 15,
    'c': 10,
    'd': 5
}

df_ciq = convert_ratings_to_numeric(df_ciq, 'rating', conversion_dict)
# Out:
# Warning: 280 ratings could not be converted and are set as NaN.

# %%
# Use the country_converter to convert to name_short
df_ciq['home_country'] = coco.convert(names=df_ciq['home_country'], to='name_short')
df_ciq[['home_country']] = df_ciq[['home_country']].apply(lambda x: x.str.lower())
# Out:
# nan not found in ISO3
# nan not found in ISO3

# %%
# Save the preprocessed ciq file as csv
df_ciq.to_csv('CIQ_data_DS_LAB_Preprocessed.csv', index=False)

# %% [markdown]
# # Merge industry, exchange, city and country from 2023 CIQ data and financial data to the network files

# %%
# Read previously saved and preprocessed 2023 ciq data
df_ciq = pd.read_csv('CIQ_data_DS_LAB_Preprocessed.csv')

# %%
def ciq_data_into_network_format(labeled_network_file, ciq_data):

    # Initialize an empty list for the new rows
    new_rows = []

    # Specify the columns to extract from df_ciq - we assume that those four attributes do not change over time
    columns_to_extract = ['home_city', 'home_country', 'industry', 'exchange']

    # Get a list of unique companies from labeled_network_file
    companies_in_networkfile = labeled_network_file['company'].unique()

    # Iterate over all rows in df_ciq
    for _, row in df_ciq.iterrows():
        company_name = row['name']
        # Check if the company is in labeled_network_file
        if company_name in companies_in_networkfile:
            for col in columns_to_extract:
                # Skip the 'name' column as it is used for the company_name
                if col != 'name':
                    # Check if the column value is not NaN
                    if pd.notna(row[col]):
                        new_row = {
                            'company': company_name,
                            'attribute': f"{row[col]}",
                            'label': col
                        }
                        new_rows.append(new_row)

    # Convert the list of dictionaries to a DataFrame
    new_rows_df = pd.DataFrame(new_rows)

    return new_rows_df

# %%
# We assume that ceo, cfo, customer, supplier and boardmember did not change much over one year.
# Therefore, these attributes are additionally merged to the 2022 network file.
def ciq_data_into_network_format_2022(labeled_network_file, ciq_data):

    # Initialize an empty list for the new rows
    new_rows = []

    # Get a list of unique companies from labeled_network_file
    companies_in_networkfile = labeled_network_file['company'].unique()

    # Iterate over all rows in df_ciq
    for _, row in df_ciq.iterrows():
        company_name = row['name']
        # Check if the company is in labeled_network_file
        if company_name in companies_in_networkfile:
            for col in df_ciq.columns:
                # Skip the 'name' column as it is used for the company_name
                if col != 'name':
                    # Check if the column value is not NaN
                    if pd.notna(row[col]):
                        new_row = {
                            'company': company_name,
                            'attribute': f"{row[col]}",
                            'label': col
                        }
                        new_rows.append(new_row)

    # Convert the list of dictionaries to a DataFrame
    new_rows_df = pd.DataFrame(new_rows)

    # Update the 'label' column where it contains 'bm', 'supplier' or 'customer' 
    new_rows_df.loc[new_rows_df['label'].str.contains('bm'), 'label'] = 'bm'
    new_rows_df.loc[new_rows_df['label'].str.contains('supplier'), 'label'] = 'supplier'
    new_rows_df.loc[new_rows_df['label'].str.contains('customer'), 'label'] = 'customer'

    return new_rows_df

# %%
# Apply the ciq_data_into_network_format function for 2011, 2013, 2016 and 2022
ciq_2011 = ciq_data_into_network_format(labeled_2011_updated, df_ciq)
ciq_2013 = ciq_data_into_network_format(labeled_2013_updated, df_ciq)
ciq_2016 = ciq_data_into_network_format(labeled_2016_updated, df_ciq)
ciq_2022 = ciq_data_into_network_format_2022(labeled_2022_updated, df_ciq)

# %%
# Read the financial data
fin_2011 = pd.read_excel('../Files/BDO_uploads/CIQ_data_2011.xlsx')
fin_2013 = pd.read_excel('../Files/BDO_uploads/CIQ_data_2013.xlsx')
fin_2016 = pd.read_excel('../Files/BDO_uploads/CIQ_data_2016.xlsx')
fin_2022 = pd.read_excel('../Files/BDO_uploads/CIQ_data_2022.xlsx')

# %%
def financial_data_into_network_format(labeled_network_file, financial_data):

    # Change the column names to lowercase
    financial_data.columns = [col.lower() for col in financial_data.columns]

    # Drop the 'isin' column
    financial_data = financial_data.drop('isin', axis=1)

    # Change the 'name' column to lowercase
    financial_data[['name']] = financial_data[['name']].apply(lambda x: x.str.lower())

    # Initialize an empty list for the new rows
    new_rows_fin = []

    # Get a list of unique companies from labeled_network_file
    companies_in_networkfile = labeled_network_file['company'].unique()

    # Iterate over all rows in financial_data
    for _, row in financial_data.iterrows():
        company_name = row['name']
        # Check if the company is in testfile_2011
        if company_name in companies_in_networkfile:
            for col in financial_data.columns:
                # Skip the 'name' column as it is used for the company_name
                if col != 'name':
                    # Check if the column value is not NaN
                    if pd.notna(row[col]):
                        new_row = {
                            'company': company_name,
                            'attribute': row[col],
                            'label': col
                        }
                        new_rows_fin.append(new_row)

    # Convert the list of dictionaries to a DataFrame
    new_rows_fin_df = pd.DataFrame(new_rows_fin)

    return new_rows_fin_df

# %%
# Apply the financial_data_into_network_format function for 2011, 2013, 2016 and 2022
fin_2011_update = financial_data_into_network_format(labeled_2011_updated, fin_2011)
fin_2013_update = financial_data_into_network_format(labeled_2013_updated, fin_2013)
fin_2016_update = financial_data_into_network_format(labeled_2016_updated, fin_2016)
fin_2022_update = financial_data_into_network_format(labeled_2022_updated, fin_2022)

# %%
# Concatenate the 2023 ciq data and financial data to the network files
network_2011_updated = pd.concat([labeled_2011_updated, ciq_2011, fin_2011_update], ignore_index=True)
network_2013_updated = pd.concat([labeled_2013_updated, ciq_2013, fin_2013_update], ignore_index=True)
network_2016_updated = pd.concat([labeled_2016_updated, ciq_2016, fin_2016_update], ignore_index=True)
network_2022_updated = pd.concat([labeled_2022_updated, ciq_2022, fin_2022_update], ignore_index=True)

# %%
def sort_network_files(labeled_network_file):

    # Define a new order of columns
    new_order = ['company', 'label', 'attribute']

    # Reorder the columns
    labeled_network_file = labeled_network_file[new_order]

    # Sort the dataframe by company and label
    labeled_network_file = labeled_network_file.sort_values(by=['company', 'label'])

    return labeled_network_file

# %%
def filter_network_files_dach(labeled_network_file):

    # Filtering to DACH region
    # Find companies that meet the criteria
    criteria = (labeled_network_file['label'] == 'home_country') & labeled_network_file['attribute'].isin(['austria', 'germany', 'switzerland'])
    companies_meeting_criteria = labeled_network_file[criteria]['company'].unique()

    # Filter the DataFrame to include only these companies
    updated_network_file = labeled_network_file[labeled_network_file['company'].isin(companies_meeting_criteria)]

    return updated_network_file

# %%
# Apply the sort_network_files function for 2011, 2013, 2016 and 2022
network_2011_all = sort_network_files(network_2011_updated)
network_2013_all = sort_network_files(network_2013_updated)
network_2016_all = sort_network_files(network_2016_updated)
network_2022_all = sort_network_files(network_2022_updated)

# %%
# Apply the filter_network_files_dach function for 2011, 2013, 2016 and 2022
network_2011_dach = filter_network_files_dach(network_2011_all)
network_2013_dach = filter_network_files_dach(network_2013_all)
network_2016_dach = filter_network_files_dach(network_2016_all)
network_2022_dach = filter_network_files_dach(network_2022_all)

# %%
# Save the updated network files as csv - ALL
network_2011_all.to_csv('labeled_network_2011_20240114.csv', index=False)
network_2013_all.to_csv('labeled_network_2013_20240114.csv', index=False)
network_2016_all.to_csv('labeled_network_2016_20240114.csv', index=False)
network_2022_all.to_csv('labeled_network_2022_20240114.csv', index=False)

# %%
# Save the updated network files as csv - DACH
network_2011_dach.to_csv('labeled_network_2011_dach_20240114.csv', index=False)
network_2013_dach.to_csv('labeled_network_2013_dach_20240114.csv', index=False)
network_2016_dach.to_csv('labeled_network_2016_dach_20240114.csv', index=False)
network_2022_dach.to_csv('labeled_network_2022_dach_20240114.csv', index=False)
